# %% [markdown]
# <a href="https://colab.research.google.com/github/wengdazhi1-creator/data-science-toolkit/blob/main/Tutorial_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
arr1 = np.array([[1, 2], [3, 4]])

# %%
arr2 = np.random.rand(3, 4)

# %%
ones = np.ones((3, 4))
zeros = np.zeros((3, 4))

# %%
arr3 = np.random.rand(6, 3)
transposed = arr3.T

# %%
n, p, m = 2, 3, 4
arr4 = np.random.rand(n, p)
arr5 = np.random.rand(p, m)
dot_product = np.dot(arr4, arr5)
